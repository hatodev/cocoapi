# %%
# Importing dependencies
# %matplotlib inline
from pycocotools.coco import COCO
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import pylab
pylab.rcParams['figure.figsize'] = (8.0, 10.0)

from SpUtils import *

# %%
# Setup path to dataset and its annotation
dataDir='/home/hatodev/Desktop/darknet/scripts/coco'
dataType='val2014'
annFile='{}/annotations/instances_{}.json'.format(dataDir,dataType)
# Initialize COCO API for instance annotations
coco=COCO(annFile)
# Out:
# loading annotations into memory...
# Done (t=5.17s)
# creating index...
# index created!

# %%
# Get category ID by keyword
catIds = coco.getCatIds(catNms=['person'])
# Get image ID from category ID
imgIds = coco.getImgIds(catIds=catIds)
# Print length of imgIds
#print("Length of imgIds : {}".format(len(imgIds)))
# Get a random index in imgIds
#print("Randint result : {}".format(np.random.randint(0, len(imgIds))))
# Get a random image by picking randomly from imgIds
# img = coco.loadImgs(imgIds[np.random.randint(0,len(imgIds))])[0]
# Print all information of an image
#print("A sample image info:\n{}".format(img))
# Read picked image and display it 
#I = io.imread('%s/images/%s/%s'%(dataDir,dataType,img['file_name']))
#plt.axis('off')
#plt.imshow(I)
#plt.show()

subDatasetLength = 500
subPerson = imgIds[:subDatasetLength]
subPersonTrain = subPerson[:int(subDatasetLength*0.8)]
subPersonVal = subPerson[int(subDatasetLength*0.8):]
print(len(subPersonTrain))
print(len(subPersonVal))
print("Train set: ")
for i, ind in enumerate(subPersonTrain):
    print("{} : {}".format(i, (coco.loadImgs(ind)[0])['file_name']))
print("Val set: ")
for i, ind in enumerate(subPersonVal):
    print("{} : {}".format(i, (coco.loadImgs(ind)[0])['file_name']))
    
print(len(subPersonDataset))
    
# print(coco.loadImgs(imgIds[np.random.randint(0,len(imgIds))])[0])
# Out:
# 400
# 100
# Train set:
# 0 : COCO_val2014_000000262148.jpg
# 1 : COCO_val2014_000000393226.jpg
# 2 : COCO_val2014_000000262161.jpg
# 3 : COCO_val2014_000000131089.jpg
# 4 : COCO_val2014_000000393243.jpg
# 5 : COCO_val2014_000000262175.jpg
# 6 : COCO_val2014_000000131108.jpg
# 7 : COCO_val2014_000000131115.jpg
# 8 : COCO_val2014_000000524333.jpg
# 9 : COCO_val2014_000000393267.jpg
# 10 : COCO_val2014_000000262197.jpg
# 11 : COCO_val2014_000000393271.jpg
# 12 : COCO_val2014_000000262200.jpg
# 13 : COCO_val2014_000000131138.jpg
# 14 : COCO_val2014_000000393284.jpg
# 15 : COCO_val2014_000000000074.jpg
# 16 : COCO_val2014_000000131152.jpg
# 17 : COCO_val2014_000000524373.jpg
# 18 : COCO_val2014_000000262229.jpg
# 19 : COCO_val2014_000000262235.jpg
# 20 : COCO_val2014_000000262242.jpg
# 21 : COCO_val2014_000000262274.jpg
# 22 : COCO_val2014_000000262275.jpg
# 23 : COCO_val2014_000000000136.jpg
# 24 : COCO_val2014_000000000139.jpg
# 25 : COCO_val2014_000000524431.jpg
# ...
